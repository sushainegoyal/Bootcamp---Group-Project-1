# %%
import requests 
import pandas as pd
import numpy as np
import re

# %%
maindf = pd.DataFrame({"Address":''},index=[np.arange(1,50)])
maindf["Latitude"]=""
maindf["Longitude"]=""
maindf["Property Type"]=""
maindf["Lease Price"]=""
maindf["Sale Price"]= ""    
maindf['SizeInterior']=""
maindf["Total Size"]=""
maindf.head()
# Out:
#   Address Latitude Longitude Property Type Lease Price Sale Price  \
# 1
# 2
# 3
# 4
# 5
#
#   SizeInterior Total Size
# 1
# 2
# 3
# 4
# 5

# %%
Querycounter = 1
responses = []
x=0

while x<6:
    
    for index, row in maindf.iterrows(): 
        x+=1
        try:
            latmin = np.random.uniform(low=40.3, high=43.6)
            latmax = np.random.uniform(low=43.6, high=43.9)

            lngmin = np.random.uniform(low=-75.6, high=-79.9)            
            lngmax = np.random.uniform(low=-79.3, high=-79.6)


            url = 'https://api2.realtor.ca/Listing.svc/PropertySearch_Post'
            body = {"CultureId":1,
            "ApplicationId":1,
            "PropertySearchTypeId":1,
            "TransactionTypeID":2,
            "BuildingTypeId":0,
            "LongitudeMin":{lngmin},
            "LongitudeMax":{lngmax},
            "LatitudeMin":{latmin},
            "LatitudeMax":{latmax},
            "PriceMin":100000,
            "RecordsPerPage":10,
            "CurrentPage":[x]}

            response = requests.post(url, data=body).json()
            responses.append(response)
            print(f'Query {Querycounter}')
            Querycounter+=1

            if response['Results'][0]['Property']['Address']['AddressText'] in maindf['Address'].unique():
                continue
            else:
                maindf.loc[index, "Latitude"] = response['Results'][0]['Property']['Address']['Latitude']  
                maindf.loc[index, "Longitude"] = response['Results'][0]['Property']['Address']['Longitude']
                maindf.loc[index,"Address"] = response['Results'][0]['Property']['Address']['AddressText']        

            maindf.loc[index,"Property Type"] = response['Results'][0]['Property']['Type']

        except:
            print('Error')    

        try:
            maindf.loc[index,"Total Size"] = response['Results'][0]['Land']['SizeTotal']

        except:   
            maindf.loc[index,"Total Size"] = ""    

        try:
            maindf.loc[index,"Sale Price"] = response['Results'][0]['Property']['Price']
        except:
            maindf.loc[index,"Sale Price"] = ""

        try:
            print(response['Results'][0]['Building']['SizeInterior'])
            maindf.loc[index,"Sq. Ftg."] = response['Results'][0]['Building']['SizeInterior']
        except:
            print('Size invalid')
            maindf.loc[index,"Sq. Ftg."] = ""
# Out:
# Query 1
# Size invalid
# Query 2
# Size invalid
# Query 3
# Size invalid
# Query 4
# Size invalid
# Query 5
# Size invalid
# Query 6
# Size invalid
# Query 7
# Size invalid
# Query 8
# 739 sqft
# Query 9
# 500 sqft
# Query 10
# Size invalid
# Query 11
# Size invalid
# Query 12
# 840 sqft
# Query 13
# Size invalid
# Query 14
# Size invalid
# Query 15
# Size invalid
# Query 16
# Size invalid
# Query 17
# 780.0000
# Query 18
# Size invalid
# Query 19
# 850.0000
# Query 20
# Query 21
# Size invalid
# Query 22
# Size invalid
# Query 23
# Size invalid
# Query 24
# Size invalid
# Query 25
# Size invalid
# Query 26
# Size invalid
# Query 27
# 700 sqft
# Query 28
# Size invalid
# Query 29
# Size invalid
# Query 30
# Size invalid
# Query 31
# Size invalid
# Query 32
# Size invalid
# Query 33
# 1142 sqft
# Query 34
# Size invalid
# Query 35
# Size invalid
# Query 36
# Size invalid
# Query 37
# Size invalid
# Query 38
# Size invalid
# Query 39
# Size invalid
# Query 40
# 811 sqft
# Query 41
# 1037 sqft
# Query 42
# Size invalid
# Query 43
# Size invalid
# Query 44
# Size invalid
# Query 45
# Query 46
# 988 sqft
# Query 47
# Size invalid
# Query 48
# 1148 sqft
# Query 49
# 965 sqft

# %%
maindf
# Out:
#                                               Address          Latitude  \
# 1   257 KING STREET #lot 15|Thorndale, Ontario N0M2P0         43.104376
# 2        4 THIMBLEWEED DRIVE|Bayfield, Ontario N0M1G0         43.551717
# 3    1282 Chebogue Road|Rockville, Nova Scotia B5A5G2        43.7766652
# 4   5660 Shore Road|North West Harbour, Nova Scoti...         43.563024
# 5   10 River Road|Port L&apos;Hebert, Nova Scotia ...  43.8032677769722
# 6        26561 DOWNIE LINE|West Lorne, Ontario N0L2P0         42.641056
# 7   17196 LAKESHORE ROAD|Rondeau Park, Ontario N0P1X0         42.272387
# 8        3 Claybank Crescent|Seaforth, Ontario N0K1W0         43.515088
# 9             118 Otto Drive|Puslinch, Ontario N0B2J0         43.366237
# 10  50 Commission Street|Sandy Point, Nova Scotia ...         43.745164
# 11              1685 CADILLAC|Windsor, Ontario N8Y2V6         42.308602
# 12         8 Popular Lane|Huron Haven, Ontario N7A3Y3         43.785347
# 13           251 HAZELTON LANE|Exeter, Ontario N0M1S1         43.356571
# 14  314 Hwy 308 Morris Island Highway|Morris Islan...  43.7486142102407
# 15  384 ST. CHARLES STREET|Belle River, Ontario N0...         42.291796
# 16  640 GREY STREET Unit# 306|Brantford, Ontario N...         43.148921
# 17       4415 Timothy Lane|Beamsville, Ontario L0R1B1         43.173107
# 18               1015 WINDSOR|Windsor, Ontario N9A1K3         42.309628
# 19              6501 ABBOTT|Lakeshore, Ontario N0P1J0         42.230002
# 20
# 21  1107 -  375 KING Street N|Waterloo, Ontario N2...         43.482503
# 22   297 WHITING STREET #16|Ingersoll, Ontario N5C3P7         43.023924
# 23  583 MORNINGTON AVENUE #110|London, Ontario N5Y3E9         43.003217
# 24  1078 Hwy 330 Centreville Road|Centreville, Nov...        43.5196128
# 25  3 -  167 Waterloo Street|Mitchell, Ontario N0K1N0           43.4678
# 26         7 Main Street|Yarmouth, Nova Scotia B5A1K3         43.820552
# 27          115 Beaver Street|Thorold, Ontario L2V1B8         43.104262
# 28  #1110 -812 BURNHAMTHORPE RD|Toronto, Ontario M...        43.6396794
# 29               654 WILLIAM|Tecumseh, Ontario N8N2A1         42.320567
# 30  #122 -2170 BROMSGROVE RD|Mississauga, Ontario ...        43.5118055
# 31    297 WHITING STREET #9|Ingersoll, Ontario N5C3P7         43.024599
# 32         667 WINDSOR AVENUE|Windsor, Ontario N9A1J6         42.314429
# 33  190 -  3033 Townline Road|Stevensville, Ontari...         42.960047
# 34         188 MAITLAND STREET|London, Ontario N6B2X7         42.980978
# 35  #804 -1359 WHITE OAKS BLVD|Oakville, Ontario L...         43.472001
# 36  3795 SOUTHWINDS Unit# 404|Windsor, Ontario N9G2N7         42.251968
# 37           256 HAZELTON LANE|Exeter, Ontario N0M1S1         43.356571
# 38  42 Oakvale Street|Clarks Harbour, Nova Scotia ...  43.4419356092456
# 39       55 Maddison Street W|Monkton, Ontario N0K1P0         43.587624
# 40  217 -  399 Queen Street S|Kitchener, Ontario N...         43.445118
# 41        101 -  50 GIBSON Street|Ayr, Ontario N0B1E0         43.287175
# 42       #103 -32 FIELDWAY RD|Toronto, Ontario M8Z3L2        43.6419167
# 43     LOT 22 MASTERS DRIVE|Woodstock, Ontario N4T0L2         43.153128
# 44     ##523 -257 HEMLOCK ST|Waterloo, Ontario N2L3R4         43.475722
# 45
# 46    82 -  340 Front Road|Port Rowan, Ontario N0E1P0          42.64127
# 47      2756 COUNTY RD 42|St. Joachim, Ontario N0R1S0         42.271706
# 48        368 PEEL Street|New Hamburg, Ontario N3A1E5         43.373544
# 49  188 -  17 Old Pine Trail|St. Catharines, Ontar...         43.186397
#
#             Longitude  Property Type Lease Price Sale Price SizeInterior  \
# 1          -81.143003  Single Family               $100,000
# 2           -81.70127  Single Family               $100,000
# 3         -66.1084398  Single Family               $109,000
# 4           -65.41442  Single Family               $119,000
# 5   -64.9320517301467  Single Family               $125,000
# 6          -81.601404  Single Family               $120,000
# 7          -81.843226  Single Family               $124,900
# 8          -81.396646  Single Family               $135,000
# 9          -80.074165  Single Family               $139,500
# 10         -65.308796  Single Family               $159,000
# 11         -82.991029  Single Family               $129,900
# 12         -81.701277  Single Family               $133,000
# 13         -81.472531  Single Family               $155,000
# 14  -65.8900454209015  Single Family               $155,000
# 15          -82.70063  Single Family               $149,900
# 16         -80.215356  Single Family               $187,000
# 17         -79.453332  Single Family               $159,900
# 18         -83.030636  Single Family               $169,900
# 19         -82.551374  Single Family               $169,900
# 20
# 21         -80.527056  Single Family               $194,900
# 22         -80.879813  Single Family               $175,000
# 23          -81.21176  Single Family               $164,900
# 24        -65.6158224  Single Family               $169,000
# 25         -81.190582  Single Family               $174,900
# 26         -66.121768  Single Family               $229,500
# 27         -79.197077  Single Family               $199,900
# 28        -79.5815659  Single Family               $565,000
# 29         -82.885608  Single Family               $179,900
# 30        -79.6369205  Single Family               $489,900
# 31         -80.878986  Single Family               $199,000
# 32         -83.033599  Single Family               $198,400
# 33         -79.033353  Single Family               $199,900
# 34         -81.233476  Single Family               $229,900
# 35        -79.6934883  Single Family               $599,900
# 36         -83.026319  Single Family               $209,900
# 37         -81.472531  Single Family               $225,000
# 38  -65.6274345629822  Single Family               $210,000
# 39         -81.084709  Single Family               $371,900
# 40          -80.49342  Single Family               $364,900
# 41         -80.451125  Single Family               $289,900
# 42        -79.5280486  Single Family               $585,000
# 43         -80.777584  Single Family               $223,835
# 44         -80.532137  Single Family               $299,000
# 45
# 46         -80.430817  Single Family               $259,900
# 47         -82.632064  Single Family               $229,900
# 48         -80.704863  Single Family               $257,000
# 49         -79.227064  Single Family               $234,900
#
#                     Total Size   Sq. Ftg.
# 1       0.21 ac|under 1/2 acre
# 2       0.16 ac|under 1/2 acre
# 3                  1 - 3 acres
# 4                 3 - 10 acres
# 5               under 1/2 acre
# 6                 1/2 - 1 acre
# 7                           0X
# 8               under 1/2 acre   739 sqft
# 9               under 1/2 acre   500 sqft
# 10              under 1/2 acre
# 11                   30X100 FT
# 12              under 1/2 acre   840 sqft
# 13       0.5 ac|under 1/2 acre
# 14                1/2 - 1 acre
# 15                64.99X100 FT
# 16                       0XN/A
# 17  LEASED LAND|under 1/2 acre   780.0000
# 18                      30X128
# 19                48.16X194.50   850.0000
# 20                                    NaN
# 21              under 1/2 acre
# 22      0.13 ac|under 1/2 acre
# 23
# 24                 1 - 3 acres
# 25                     Unknown
# 26              under 1/2 acre
# 27              under 1/2 acre   700 sqft
# 28
# 29                 39.99X99.75
# 30
# 31      0.21 ac|under 1/2 acre
# 32                46.49X129 FT
# 33              under 1/2 acre  1142 sqft
# 34              under 1/2 acre
# 35
# 36                          0X
# 37       0.5 ac|under 1/2 acre
# 38                 1 - 3 acres
# 39              under 1/2 acre
# 40              under 1/2 acre   811 sqft
# 41                     Unknown  1037 sqft
# 42
# 43       0.2 ac|under 1/2 acre
# 44
# 45                                    NaN
# 46              under 1/2 acre   988 sqft
# 47                80.58X190.29
# 48              under 1/2 acre  1148 sqft
# 49                     Unknown   965 sqft

# %%
maindfclean = maindf.loc[maindf['Address']!="",:]
maindfclean.reset_index(drop=True)
# Out:
#                                               Address          Latitude  \
# 0   257 KING STREET #lot 15|Thorndale, Ontario N0M2P0         43.104376
# 1        4 THIMBLEWEED DRIVE|Bayfield, Ontario N0M1G0         43.551717
# 2    1282 Chebogue Road|Rockville, Nova Scotia B5A5G2        43.7766652
# 3   5660 Shore Road|North West Harbour, Nova Scoti...         43.563024
# 4   10 River Road|Port L&apos;Hebert, Nova Scotia ...  43.8032677769722
# 5        26561 DOWNIE LINE|West Lorne, Ontario N0L2P0         42.641056
# 6   17196 LAKESHORE ROAD|Rondeau Park, Ontario N0P1X0         42.272387
# 7        3 Claybank Crescent|Seaforth, Ontario N0K1W0         43.515088
# 8             118 Otto Drive|Puslinch, Ontario N0B2J0         43.366237
# 9   50 Commission Street|Sandy Point, Nova Scotia ...         43.745164
# 10              1685 CADILLAC|Windsor, Ontario N8Y2V6         42.308602
# 11         8 Popular Lane|Huron Haven, Ontario N7A3Y3         43.785347
# 12           251 HAZELTON LANE|Exeter, Ontario N0M1S1         43.356571
# 13  314 Hwy 308 Morris Island Highway|Morris Islan...  43.7486142102407
# 14  384 ST. CHARLES STREET|Belle River, Ontario N0...         42.291796
# 15  640 GREY STREET Unit# 306|Brantford, Ontario N...         43.148921
# 16       4415 Timothy Lane|Beamsville, Ontario L0R1B1         43.173107
# 17               1015 WINDSOR|Windsor, Ontario N9A1K3         42.309628
# 18              6501 ABBOTT|Lakeshore, Ontario N0P1J0         42.230002
# 19  1107 -  375 KING Street N|Waterloo, Ontario N2...         43.482503
# 20   297 WHITING STREET #16|Ingersoll, Ontario N5C3P7         43.023924
# 21  583 MORNINGTON AVENUE #110|London, Ontario N5Y3E9         43.003217
# 22  1078 Hwy 330 Centreville Road|Centreville, Nov...        43.5196128
# 23  3 -  167 Waterloo Street|Mitchell, Ontario N0K1N0           43.4678
# 24         7 Main Street|Yarmouth, Nova Scotia B5A1K3         43.820552
# 25          115 Beaver Street|Thorold, Ontario L2V1B8         43.104262
# 26  #1110 -812 BURNHAMTHORPE RD|Toronto, Ontario M...        43.6396794
# 27               654 WILLIAM|Tecumseh, Ontario N8N2A1         42.320567
# 28  #122 -2170 BROMSGROVE RD|Mississauga, Ontario ...        43.5118055
# 29    297 WHITING STREET #9|Ingersoll, Ontario N5C3P7         43.024599
# 30         667 WINDSOR AVENUE|Windsor, Ontario N9A1J6         42.314429
# 31  190 -  3033 Townline Road|Stevensville, Ontari...         42.960047
# 32         188 MAITLAND STREET|London, Ontario N6B2X7         42.980978
# 33  #804 -1359 WHITE OAKS BLVD|Oakville, Ontario L...         43.472001
# 34  3795 SOUTHWINDS Unit# 404|Windsor, Ontario N9G2N7         42.251968
# 35           256 HAZELTON LANE|Exeter, Ontario N0M1S1         43.356571
# 36  42 Oakvale Street|Clarks Harbour, Nova Scotia ...  43.4419356092456
# 37       55 Maddison Street W|Monkton, Ontario N0K1P0         43.587624
# 38  217 -  399 Queen Street S|Kitchener, Ontario N...         43.445118
# 39        101 -  50 GIBSON Street|Ayr, Ontario N0B1E0         43.287175
# 40       #103 -32 FIELDWAY RD|Toronto, Ontario M8Z3L2        43.6419167
# 41     LOT 22 MASTERS DRIVE|Woodstock, Ontario N4T0L2         43.153128
# 42     ##523 -257 HEMLOCK ST|Waterloo, Ontario N2L3R4         43.475722
# 43    82 -  340 Front Road|Port Rowan, Ontario N0E1P0          42.64127
# 44      2756 COUNTY RD 42|St. Joachim, Ontario N0R1S0         42.271706
# 45        368 PEEL Street|New Hamburg, Ontario N3A1E5         43.373544
# 46  188 -  17 Old Pine Trail|St. Catharines, Ontar...         43.186397
#
#             Longitude  Property Type Lease Price Sale Price SizeInterior  \
# 0          -81.143003  Single Family               $100,000
# 1           -81.70127  Single Family               $100,000
# 2         -66.1084398  Single Family               $109,000
# 3           -65.41442  Single Family               $119,000
# 4   -64.9320517301467  Single Family               $125,000
# 5          -81.601404  Single Family               $120,000
# 6          -81.843226  Single Family               $124,900
# 7          -81.396646  Single Family               $135,000
# 8          -80.074165  Single Family               $139,500
# 9          -65.308796  Single Family               $159,000
# 10         -82.991029  Single Family               $129,900
# 11         -81.701277  Single Family               $133,000
# 12         -81.472531  Single Family               $155,000
# 13  -65.8900454209015  Single Family               $155,000
# 14          -82.70063  Single Family               $149,900
# 15         -80.215356  Single Family               $187,000
# 16         -79.453332  Single Family               $159,900
# 17         -83.030636  Single Family               $169,900
# 18         -82.551374  Single Family               $169,900
# 19         -80.527056  Single Family               $194,900
# 20         -80.879813  Single Family               $175,000
# 21          -81.21176  Single Family               $164,900
# 22        -65.6158224  Single Family               $169,000
# 23         -81.190582  Single Family               $174,900
# 24         -66.121768  Single Family               $229,500
# 25         -79.197077  Single Family               $199,900
# 26        -79.5815659  Single Family               $565,000
# 27         -82.885608  Single Family               $179,900
# 28        -79.6369205  Single Family               $489,900
# 29         -80.878986  Single Family               $199,000
# 30         -83.033599  Single Family               $198,400
# 31         -79.033353  Single Family               $199,900
# 32         -81.233476  Single Family               $229,900
# 33        -79.6934883  Single Family               $599,900
# 34         -83.026319  Single Family               $209,900
# 35         -81.472531  Single Family               $225,000
# 36  -65.6274345629822  Single Family               $210,000
# 37         -81.084709  Single Family               $371,900
# 38          -80.49342  Single Family               $364,900
# 39         -80.451125  Single Family               $289,900
# 40        -79.5280486  Single Family               $585,000
# 41         -80.777584  Single Family               $223,835
# 42         -80.532137  Single Family               $299,000
# 43         -80.430817  Single Family               $259,900
# 44         -82.632064  Single Family               $229,900
# 45         -80.704863  Single Family               $257,000
# 46         -79.227064  Single Family               $234,900
#
#                     Total Size   Sq. Ftg.
# 0       0.21 ac|under 1/2 acre
# 1       0.16 ac|under 1/2 acre
# 2                  1 - 3 acres
# 3                 3 - 10 acres
# 4               under 1/2 acre
# 5                 1/2 - 1 acre
# 6                           0X
# 7               under 1/2 acre   739 sqft
# 8               under 1/2 acre   500 sqft
# 9               under 1/2 acre
# 10                   30X100 FT
# 11              under 1/2 acre   840 sqft
# 12       0.5 ac|under 1/2 acre
# 13                1/2 - 1 acre
# 14                64.99X100 FT
# 15                       0XN/A
# 16  LEASED LAND|under 1/2 acre   780.0000
# 17                      30X128
# 18                48.16X194.50   850.0000
# 19              under 1/2 acre
# 20      0.13 ac|under 1/2 acre
# 21
# 22                 1 - 3 acres
# 23                     Unknown
# 24              under 1/2 acre
# 25              under 1/2 acre   700 sqft
# 26
# 27                 39.99X99.75
# 28
# 29      0.21 ac|under 1/2 acre
# 30                46.49X129 FT
# 31              under 1/2 acre  1142 sqft
# 32              under 1/2 acre
# 33
# 34                          0X
# 35       0.5 ac|under 1/2 acre
# 36                 1 - 3 acres
# 37              under 1/2 acre
# 38              under 1/2 acre   811 sqft
# 39                     Unknown  1037 sqft
# 40
# 41       0.2 ac|under 1/2 acre
# 42
# 43              under 1/2 acre   988 sqft
# 44                80.58X190.29
# 45              under 1/2 acre  1148 sqft
# 46                     Unknown   965 sqft

# %%
response['Paging']
# Out:
# {'RecordsPerPage': 10,
#  'CurrentPage': 49,
#  'TotalRecords': 18906,
#  'MaxRecords': 500,
#  'TotalPages': 50,
#  'RecordsShowing': 500,
#  'Pins': 7856}
